# %% [markdown]
# <h1> Computational Drug Discovery </h1>

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (0.10.8)
# Requirement already satisfied: urllib3 in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (from chembl_webresource_client) (1.26.15)
# Requirement already satisfied: requests>=2.18.4 in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (from chembl_webresource_client) (2.29.0)
# Requirement already satisfied: requests-cache~=0.7.0 in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: easydict in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (2023.5.7)
# Requirement already satisfied: attrs<22.0,>=21.2 in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.4.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /Users/enriqueviv/anaconda3/lib/python3.10/site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)

# %%
#Import libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# <h2>Search for Target protein </h2>

# %% [markdown]
# <h3> Target search for <h3>

# %%
target = new_client.target
target_query = target.search("heart")
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5                                                  []
# 6   [{'xref_id': 'P05413', 'xref_name': None, 'xre...
# 7   [{'xref_id': 'P00336', 'xref_name': None, 'xre...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12  [{'xref_id': 'P07195', 'xref_name': None, 'xre...
# 13  [{'xref_id': 'Q16816', 'xref_name': None, 'xre...
# 14  [{'xref_id': 'Q13510', 'xref_name': None, 'xre...
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18  [{'xref_id': 'P21980', 'xref_name': None, 'xre...
# 19                                                 []
# 20                                                 []
# 21                                                 []
#
#                     organism  \
# 0      Oryctolagus cuniculus
# 1               Mus musculus
# 2          Rattus norvegicus
# 3            Cavia porcellus
# 4   Hoplobatrachus tigerinus
# 5                 Bos taurus
# 6               Homo sapiens
# 7                 Sus scrofa
# 8          Rattus norvegicus
# 9      Oryctolagus cuniculus
# 10              Homo sapiens
# 11              Mus musculus
# 12              Homo sapiens
# 13              Homo sapiens
# 14              Homo sapiens
# 15              Homo sapiens
# 16              Homo sapiens
# 17         Rattus norvegicus
# 18              Homo sapiens
# 19              Homo sapiens
# 20         Rattus norvegicus
# 21              Homo sapiens
#
#                                             pref_name  score  \
# 0                                               Heart   17.0
# 1                                               Heart   17.0
# 2                                               Heart   17.0
# 3                                               Heart   17.0
# 4                                               Heart   17.0
# 5                             Heart phosphodiesterase   15.0
# 6                   Fatty acid binding protein muscle   13.0
# 7                     L-lactate dehydrogenase B chain   12.0
# 8                     L-lactate dehydrogenase B chain   12.0
# 9                     L-lactate dehydrogenase B chain   12.0
# 10                       Gap junction alpha-1 protein   12.0
# 11                    L-lactate dehydrogenase B chain   12.0
# 12                    L-lactate dehydrogenase B chain   11.0
# 13               Phosphorylase kinase gamma subunit 1   10.0
# 14                                    Acid ceramidase    9.0
# 15  G protein-activated inward rectifier potassium...    9.0
# 16  6-phosphofructo-2-kinase/fructose-2,6-bisphosp...    9.0
# 17  G protein-activated inward rectifier potassium...    9.0
# 18        Protein-glutamine gamma-glutamyltransferase    6.0
# 19                                      Kir3.1/Kir3.4    6.0
# 20                                      Kir3.1/Kir3.4    6.0
# 21                               Phosphorylase kinase    5.0
#
#     species_group_flag target_chembl_id  \
# 0                False     CHEMBL613689
# 1                False     CHEMBL613573
# 2                False     CHEMBL613629
# 3                False     CHEMBL613678
# 4                False    CHEMBL2367418
# 5                False    CHEMBL2111408
# 6                False       CHEMBL3344
# 7                False       CHEMBL3823
# 8                False    CHEMBL2176834
# 9                False    CHEMBL4523187
# 10               False    CHEMBL4680024
# 11               False    CHEMBL5169119
# 12               False       CHEMBL4940
# 13               False       CHEMBL4004
# 14               False       CHEMBL5463
# 15               False    CHEMBL1914278
# 16               False    CHEMBL3421525
# 17               False    CHEMBL3714708
# 18               False       CHEMBL2730
# 19               False    CHEMBL3038488
# 20               False    CHEMBL3832643
# 21               False    CHEMBL2111324
#
#                                     target_components            target_type  \
# 0                                                  []                 TISSUE
# 1                                                  []                 TISSUE
# 2                                                  []                 TISSUE
# 3                                                  []                 TISSUE
# 4                                                  []                 TISSUE
# 5   [{'accession': 'Q01061', 'component_descriptio...         PROTEIN FAMILY
# 6   [{'accession': 'P05413', 'component_descriptio...         SINGLE PROTEIN
# 7   [{'accession': 'P00336', 'component_descriptio...         SINGLE PROTEIN
# 8   [{'accession': 'P42123', 'component_descriptio...         SINGLE PROTEIN
# 9   [{'accession': 'P13490', 'component_descriptio...         SINGLE PROTEIN
# 10  [{'accession': 'P17302', 'component_descriptio...         SINGLE PROTEIN
# 11  [{'accession': 'P16125', 'component_descriptio...         SINGLE PROTEIN
# 12  [{'accession': 'P07195', 'component_descriptio...         SINGLE PROTEIN
# 13  [{'accession': 'Q16816', 'component_descriptio...         SINGLE PROTEIN
# 14  [{'accession': 'Q13510', 'component_descriptio...         SINGLE PROTEIN
# 15  [{'accession': 'P48544', 'component_descriptio...         SINGLE PROTEIN
# 16  [{'accession': 'O60825', 'component_descriptio...         SINGLE PROTEIN
# 17  [{'accession': 'P48548', 'component_descriptio...         SINGLE PROTEIN
# 18  [{'accession': 'P21980', 'component_descriptio...         SINGLE PROTEIN
# 19  [{'accession': 'P48549', 'component_descriptio...        PROTEIN COMPLEX
# 20  [{'accession': 'P63251', 'component_descriptio...        PROTEIN COMPLEX
# 21  [{'accession': 'P15735', 'component_descriptio...  PROTEIN COMPLEX GROUP
#
#     tax_id
# 0     9986
# 1    10090
# 2    10116
# 3    10141
# 4   103373
# 5     9913
# 6     9606
# 7     9823
# 8    10116
# 9     9986
# 10    9606
# 11   10090
# 12    9606
# 13    9606
# 14    9606
# 15    9606
# 16    9606
# 17   10116
# 18    9606
# 19    9606
# 20   10116
# 21    9606

# %% [markdown]
# <h3> Select and retrieve bioactivity data for L-lactate dehydrogenase B chain <h3>

# %%
selected_target = targets.target_chembl_id[12]
selected_target
# Out:
# 'CHEMBL4940'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %% [markdown]
# retrieve bioactivity data reported as IC50 value

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None     10952882                  []
# 1        None   Not Determined     10952883                  []
# 2        None   Not Determined     10952884                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL2060672  Inhibition of human recombinant LDHB (2 to 334...
# 1   CHEMBL2060672  Inhibition of human recombinant LDHB (2 to 334...
# 2   CHEMBL2060672  Inhibition of human recombinant LDHB (2 to 334...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism                 target_pref_name target_tax_id text_value  \
# 0    Homo sapiens  L-lactate dehydrogenase B chain          9606       None
# 1    Homo sapiens  L-lactate dehydrogenase B chain          9606       None
# 2    Homo sapiens  L-lactate dehydrogenase B chain          9606       None
#
#    toid  type units    uo_units upper_value value
# 0  None  IC50    uM  UO_0000065        None   7.8
# 1  None  IC50  None        None        None  None
# 2  None  IC50  None        None        None  None
#
# [3 rows x 46 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
data=pd.read_csv('bioactivity_data.csv')

# %% [markdown]
# <h3> Handling missing data </h3>

# %% [markdown]
# If any compounds has missing value for the standard value drop it

# %%
data2= data[data.standard_value.notna()]

# %%
data2.head(5)
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0          NaN              NaN     10952882                  []
# 7          NaN              NaN     10952889                  []
# 8          NaN              NaN     13298323                  []
# 9          NaN              NaN     13298324                  []
# 10         NaN              NaN     13298325                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL2060672  Inhibition of human recombinant LDHB (2 to 334...
# 7    CHEMBL2060672  Inhibition of human recombinant LDHB (2 to 334...
# 8    CHEMBL2384178  Inhibition of human recombinant carboxy-termin...
# 9    CHEMBL2384178  Inhibition of human recombinant carboxy-termin...
# 10   CHEMBL2384178  Inhibition of human recombinant carboxy-termin...
#
#    assay_type  assay_variant_accession  assay_variant_mutation bao_endpoint  \
# 0           B                      NaN                     NaN  BAO_0000190
# 7           B                      NaN                     NaN  BAO_0000190
# 8           B                      NaN                     NaN  BAO_0000190
# 9           B                      NaN                     NaN  BAO_0000190
# 10          B                      NaN                     NaN  BAO_0000190
#
#     ... target_organism                 target_pref_name target_tax_id  \
# 0   ...    Homo sapiens  L-lactate dehydrogenase B chain          9606
# 7   ...    Homo sapiens  L-lactate dehydrogenase B chain          9606
# 8   ...    Homo sapiens  L-lactate dehydrogenase B chain          9606
# 9   ...    Homo sapiens  L-lactate dehydrogenase B chain          9606
# 10  ...    Homo sapiens  L-lactate dehydrogenase B chain          9606
#
#     text_value  toid  type units    uo_units upper_value value
# 0          NaN   NaN  IC50    uM  UO_0000065         NaN   7.8
# 7          NaN   NaN  IC50    uM  UO_0000065         NaN   9.4
# 8          NaN   NaN  IC50    uM  UO_0000065         NaN  33.8
# 9          NaN   NaN  IC50    uM  UO_0000065         NaN   7.7
# 10         NaN   NaN  IC50    uM  UO_0000065         NaN   2.4
#
# [5 rows x 46 columns]

# %% [markdown]
# <h3> Data pre-processing of the bioactivity data </h3>

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
data3= data2[selection]
data3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL1232973                                     O=C(O)c1nsnc1O
# 7        CHEMBL2058994  NC(=O)C1=CN([C@@H]2O[C@H](COP(=O)(O)OP(=O)(O)O...
# 8          CHEMBL15976                                       NC(=O)C(=O)O
# 9        CHEMBL2382405  CCC(Sc1nc(-c2cccc(OC)c2)c(C#N)c(=O)[nH]1)C(=O)...
# 10       CHEMBL2382404  CCC(Sc1nc(-c2ccc(Cl)cc2)c(C#N)c(=O)[nH]1)C(=O)...
# ..                 ...                                                ...
# 231      CHEMBL5188480  O=C1NC(c2cccc(Nc3ccc(F)c(F)c3)n2)(c2cccc(Oc3cc...
# 232      CHEMBL5185237  O=C1NC(c2ccc(N3CCOCC3)cc2)(c2cccc(Nc3ccc(F)cc3...
# 233      CHEMBL5185237  O=C1NC(c2ccc(N3CCOCC3)cc2)(c2cccc(Nc3ccc(F)cc3...
# 234      CHEMBL5201115  O=C1NC(c2ccc(N3CCOCC3)cc2)(c2cccc(Oc3ccc(F)cc3...
# 235      CHEMBL5201115  O=C1NC(c2ccc(N3CCOCC3)cc2)(c2cccc(Oc3ccc(F)cc3...
#
#      standard_value
# 0            7800.0
# 7            9400.0
# 8           33800.0
# 9            7700.0
# 10           2400.0
# ..              ...
# 231           650.0
# 232             1.7
# 233            38.0
# 234             2.2
# 235            85.0
#
# [211 rows x 3 columns]

# %%
data3.to_csv('l_lactatedehydrogenase_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# <h3> Labeling compounds as either being active, inactive or intermediate </h3>
# <br>The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be active while those greater than 10,000 nM will be considered to be inactive. As for those values in between 1,000 and 10,000 nM will be referred to as intermediate.

# %%
data4= pd.read_csv('l_lactatedehydrogenase_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in data4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
data5 = pd.concat([data4, bioactivity_class], axis=1)
data5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL1232973                                     O=C(O)c1nsnc1O
# 1        CHEMBL2058994  NC(=O)C1=CN([C@@H]2O[C@H](COP(=O)(O)OP(=O)(O)O...
# 2          CHEMBL15976                                       NC(=O)C(=O)O
# 3        CHEMBL2382405  CCC(Sc1nc(-c2cccc(OC)c2)c(C#N)c(=O)[nH]1)C(=O)...
# 4        CHEMBL2382404  CCC(Sc1nc(-c2ccc(Cl)cc2)c(C#N)c(=O)[nH]1)C(=O)...
# ..                 ...                                                ...
# 206      CHEMBL5188480  O=C1NC(c2cccc(Nc3ccc(F)c(F)c3)n2)(c2cccc(Oc3cc...
# 207      CHEMBL5185237  O=C1NC(c2ccc(N3CCOCC3)cc2)(c2cccc(Nc3ccc(F)cc3...
# 208      CHEMBL5185237  O=C1NC(c2ccc(N3CCOCC3)cc2)(c2cccc(Nc3ccc(F)cc3...
# 209      CHEMBL5201115  O=C1NC(c2ccc(N3CCOCC3)cc2)(c2cccc(Oc3ccc(F)cc3...
# 210      CHEMBL5201115  O=C1NC(c2ccc(N3CCOCC3)cc2)(c2cccc(Oc3ccc(F)cc3...
#
#      standard_value         class
# 0            7800.0  intermediate
# 1            9400.0  intermediate
# 2           33800.0      inactive
# 3            7700.0  intermediate
# 4            2400.0  intermediate
# ..              ...           ...
# 206           650.0        active
# 207             1.7        active
# 208            38.0        active
# 209             2.2        active
# 210            85.0        active
#
# [211 rows x 4 columns]

# %%
data5.to_csv('l_lactatedehydrogenase_bioactivity_data_curated.csv', index=False)
